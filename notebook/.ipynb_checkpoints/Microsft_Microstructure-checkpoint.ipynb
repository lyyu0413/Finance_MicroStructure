# %% [markdown]
# # Empirical market microstructure in Python--Practice
#
# Originally, Prepared by [Vincent Grégoire](http://www.vincentgregoire.com), Department of Finance, The University of Melbourne. Modified by Linyang Yu
#
# This is a sample code to illustrate how you can merge and analyze intraday financial data.
#
# This code loads and analyzes intraday trades and quotes for all ASX20 stocks for the first two weeks of
# March 2017 using
# data from [Thomson Reuters Tick History](https://tickhistory.thomsonreuters.com/), provided by [SIRCA](https://www.sirca.org.au/).
#
# This notebook was created as supplemental material to a Python for financial research workshop for finance honours and Ph.D. students at the University of Melbourne in March of 2018.
#
# Latest version: <https://github.com/vgreg/python-finance-unimelb2018>
#
# **Outline**:
#
# - Load trades and quotes
# - Parsing timestamps (and convert from UTC)
# - Cleaning, forward filling quotes
# - Realized spread (merging asof)
# - Time-weighted depth
# - Plot something
# - Summarize data at the stock/day level

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
from datetime import datetime, date, time, timedelta
import matplotlib.pyplot as plt

# %% [markdown]
# The data requested from TRTH is in two files named "MSFT_Quote.csv" and "MSFT_Trade.csv". First, let's get a sense of the data.

# %%
# The quote data
df_temp_q = pd.read_csv('../data/MSFT_Quote.csv',parse_dates=['DATE'])
df_temp_q = df_temp_q[pd.notnull(df_temp_q['TIME'])]

df_temp_q.head()
# Out:
#   SYMBOL       DATE     TIME   BID    OFR  BIDSIZ  OFRSIZ  MODE EX  MMID
# 0   MSFT 2005-03-10  7:30:00  25.3  25.32       1       1    12  T   NaN
# 1   MSFT 2005-03-10  7:30:00  25.3  25.32       1       1    12  T   NaN
# 2   MSFT 2005-03-10  7:30:00  25.3  25.32       1       1    12  T   NaN
# 3   MSFT 2005-03-10  7:30:00  25.3  25.32       1       1    12  T   NaN
# 4   MSFT 2005-03-10  7:30:00  25.3  25.32       1       1    12  T   NaN

# %%
df_temp_q.describe()
# Out:
#                  BID            OFR         BIDSIZ         OFRSIZ  \
# count  265044.000000  265044.000000  265044.000000  265044.000000
# mean       25.224733      25.295248     409.276946     436.485097
# std         1.514449      25.659958     268.104566     276.276449
# min         0.000000       0.000000       0.000000       0.000000
# 25%        25.300000      25.310000     191.000000     219.000000
# 50%        25.320000      25.330000     391.000000     418.000000
# 75%        25.340000      25.350000     601.000000     627.000000
# max        25.520000    9000.000000    1190.000000    1153.000000
#
#                 MODE  MMID
# count  265044.000000   0.0
# mean       12.624632   NaN
# std         7.345412   NaN
# min         8.000000   NaN
# 25%        12.000000   NaN
# 50%        12.000000   NaN
# 75%        12.000000   NaN
# max        99.000000   NaN

# %% [markdown]
# As we can see the quote data has 10 columns includes the SYMBOL (represents the company), the DATE and TIME that happend, the BID (the bid price), the OFR (ask price), the bidsize and the offer size, MODE, EX AND MMID.

# %%
# the trade data
df_temp_t = pd.read_csv("../data/MSFT_Trade.csv",parse_dates=['DATE'])
df_temp_t = df_temp_t[pd.notnull(df_temp_t['TIME'])]

df_temp_t.head()
# Out:
#   SYMBOL       DATE     TIME  PRICE  SIZE  G127  CORR COND EX
# 0   MSFT 2005-03-10  8:00:00  25.41   656     0     0    T  P
# 1   MSFT 2005-03-10  8:01:01  25.36   125     0     0    T  C
# 2   MSFT 2005-03-10  8:01:01  25.36   219     0     0    T  C
# 3   MSFT 2005-03-10  8:01:01  25.36  1000     0     0    T  C
# 4   MSFT 2005-03-10  8:01:15  25.36  1000     0     0    T  C

# %%
df_temp_t.describe()
# Out:
#               PRICE          SIZE     G127          CORR
# count  87496.000000  8.749600e+04  87496.0  87496.000000
# mean      25.335050  6.760474e+02      0.0      0.001234
# std        0.035638  1.301218e+04      0.0      0.106042
# min       25.250000  1.000000e+02      0.0      0.000000
# 25%       25.310000  1.000000e+02      0.0      0.000000
# 50%       25.330000  4.000000e+02      0.0      0.000000
# 75%       25.350000  6.000000e+02      0.0      0.000000
# max       25.730000  2.500000e+06      0.0     10.000000

# %% [markdown]
# The trade data has 9 columns, includes the SYMBOL, DATE, TIME, PICE, SIZE, and other cols.

# %% [markdown]
# We can redefine the column names.

# %%
# for the qupte data
# SYMBOL	DATE	TIME	BID	OFR	BIDSIZ	OFRSIZ	MODE	EX	MMID
cols_q = ['#RIC', 'Date[L]', 'Quote Time', 'Bid Price', 'Ask Price',
        'Bid Size', 'Ask Size', 'MODE', 'Exch Time', 'MMID']
df_quotes = df_temp_q.copy()
df_quotes.columns = cols_q
df_quotes = df_quotes[['#RIC', 'Date[L]', 'Quote Time', 'Bid Price', 'Bid Size',
        'Ask Price', 'Ask Size']]
df_quotes.head()
# Out:
#    #RIC    Date[L] Quote Time  Bid Price  Bid Size  Ask Price  Ask Size
# 0  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 1  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 2  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 3  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 4  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1

# %%
# for trade data
# 	SYMBOL	DATE	TIME	PRICE	SIZE	G127	CORR	COND	EX
cols_t = ['#RIC', 'Date[L]', 'Exch Time', "Price", "Volumn","G127", "CORR","COND","EX"]
df_trades = df_temp_t.copy()
df_trades.columns = cols_t
df_trades = df_trades[['#RIC', 'Date[L]', 'Exch Time', "Price", "Volumn"]]

df_trades.head()
# Out:
#    #RIC    Date[L] Exch Time  Price  Volumn
# 0  MSFT 2005-03-10   8:00:00  25.41     656
# 1  MSFT 2005-03-10   8:01:01  25.36     125
# 2  MSFT 2005-03-10   8:01:01  25.36     219
# 3  MSFT 2005-03-10   8:01:01  25.36    1000
# 4  MSFT 2005-03-10   8:01:15  25.36    1000

# %%
len(df_quotes)
# Out:
# 265044

# %%
len(df_trades)
# Out:
# 87496

# %% [markdown]
# To parse dates and timestamps, we'll use a simple trick that saves time by assuming a lot of dates and times are the same. We parse date and time separately since there is much more redundancy in dates.

# %%
# To join dates and times, we need to account for time zone. Dates are local dates (Sydney),
# but times are in UTC.
def parse_simple_time(t):
    # The data is up to the second precision.
    # print(t.split(":"))
    return timedelta(hours=int(t.split(":")[0]), minutes=int(t.split(":")[1]),
                     seconds=int(t.split(":")[2]))

df_trades["parse_time"] = df_trades["Exch Time"].apply(parse_simple_time)

df_trades["Timestamp"] = (df_trades['Date[L]'].dt.tz_localize('UTC') + df_trades["parse_time"])

sel = (df_trades.Timestamp.dt.date != df_trades['Date[L]'].dt.date)
df_trades.loc[sel, 'Timestamp'] = df_trades.loc[sel, 'Timestamp'] - timedelta(days=1)
#df_trades.head()
# df_trades.head()
df_trades.head()
# Out:
#    #RIC    Date[L] Exch Time  Price  Volumn parse_time  \
# 0  MSFT 2005-03-10   8:00:00  25.41     656   08:00:00
# 1  MSFT 2005-03-10   8:01:01  25.36     125   08:01:01
# 2  MSFT 2005-03-10   8:01:01  25.36     219   08:01:01
# 3  MSFT 2005-03-10   8:01:01  25.36    1000   08:01:01
# 4  MSFT 2005-03-10   8:01:15  25.36    1000   08:01:15
#
#                   Timestamp
# 0 2005-03-10 08:00:00+00:00
# 1 2005-03-10 08:01:01+00:00
# 2 2005-03-10 08:01:01+00:00
# 3 2005-03-10 08:01:01+00:00
# 4 2005-03-10 08:01:15+00:00

# %%
def parse_simple_time(t):
    # The data is up to the second precision.
    # print(t.split(":"))
    return timedelta(hours=int(t.split(":")[0]), minutes=int(t.split(":")[1]),
                     seconds=int(t.split(":")[2]))

df_quotes["parse_time"] = df_quotes["Quote Time"].apply(parse_simple_time)

df_quotes["Timestamp"] = (df_quotes['Date[L]'].dt.tz_localize('UTC') + df_quotes["parse_time"])

sel = (df_quotes.Timestamp.dt.date != df_quotes['Date[L]'].dt.date)
df_quotes.loc[sel, 'Timestamp'] = df_quotes.loc[sel, 'Timestamp'] - timedelta(days=1)
df_quotes.head()
# Out:
#    #RIC    Date[L] Quote Time  Bid Price  Bid Size  Ask Price  Ask Size  \
# 0  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 1  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 2  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 3  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 4  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
#
#   parse_time                 Timestamp
# 0   07:30:00 2005-03-10 07:30:00+00:00
# 1   07:30:00 2005-03-10 07:30:00+00:00
# 2   07:30:00 2005-03-10 07:30:00+00:00
# 3   07:30:00 2005-03-10 07:30:00+00:00
# 4   07:30:00 2005-03-10 07:30:00+00:00

# %% [markdown]
# As we can see, quotes get updated only one side at a time, so we need to fill forward the quotes.
#
# We will first do the processing on one day only. It will be easier to see, and then we can write a function
# with our code to loop over every day in the sample. This is usually a good approach; when the processing is split into logical elements (i.e. stock or day) it is easier to write and to run in parallel.

# %%
quotes = df_quotes[df_quotes['Date[L]'] == datetime(2005, 3, 10)].copy()
trades = df_trades[df_trades['Date[L]'] == datetime(2005, 3, 10)].copy()

# %%
trades.head()
# Out:
#    #RIC    Date[L] Exch Time  Price  Volumn parse_time  \
# 0  MSFT 2005-03-10   8:00:00  25.41     656   08:00:00
# 1  MSFT 2005-03-10   8:01:01  25.36     125   08:01:01
# 2  MSFT 2005-03-10   8:01:01  25.36     219   08:01:01
# 3  MSFT 2005-03-10   8:01:01  25.36    1000   08:01:01
# 4  MSFT 2005-03-10   8:01:15  25.36    1000   08:01:15
#
#                   Timestamp
# 0 2005-03-10 08:00:00+00:00
# 1 2005-03-10 08:01:01+00:00
# 2 2005-03-10 08:01:01+00:00
# 3 2005-03-10 08:01:01+00:00
# 4 2005-03-10 08:01:15+00:00

# %%
quotes_cols = ['Bid Price', 'Bid Size', 'Ask Price', 'Ask Size']
quotes[quotes_cols] = quotes.groupby(['#RIC'])[quotes_cols].fillna(method='ffill')
# Missing values implie no depth
quotes[['Bid Size', 'Ask Size']] = quotes[['Bid Size', 'Ask Size']].fillna(0.0)
quotes.head()
# Out:
#    #RIC    Date[L] Quote Time  Bid Price  Bid Size  Ask Price  Ask Size  \
# 0  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 1  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 2  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 3  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 4  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
#
#   parse_time                 Timestamp
# 0   07:30:00 2005-03-10 07:30:00+00:00
# 1   07:30:00 2005-03-10 07:30:00+00:00
# 2   07:30:00 2005-03-10 07:30:00+00:00
# 3   07:30:00 2005-03-10 07:30:00+00:00
# 4   07:30:00 2005-03-10 07:30:00+00:00

# %% [markdown]
# Let's create a few measures.

# %%
quotes['MidQuote'] = (quotes['Bid Price'] + quotes['Ask Price'])/2.0
quotes['DepthOnTop'] = (quotes['Bid Size'] + quotes['Ask Size'])/2.0
quotes['Spread'] = quotes['Ask Price'] - quotes['Bid Price']
quotes['RelSpread'] = quotes['Spread']/quotes['MidQuote']

# %%
trades['Value'] = trades['Price'] * trades['Volumn']

# %%
trades.head()
# Out:
#    #RIC    Date[L] Exch Time  Price  Volumn parse_time  \
# 0  MSFT 2005-03-10   8:00:00  25.41     656   08:00:00
# 1  MSFT 2005-03-10   8:01:01  25.36     125   08:01:01
# 2  MSFT 2005-03-10   8:01:01  25.36     219   08:01:01
# 3  MSFT 2005-03-10   8:01:01  25.36    1000   08:01:01
# 4  MSFT 2005-03-10   8:01:15  25.36    1000   08:01:15
#
#                   Timestamp     Value
# 0 2005-03-10 08:00:00+00:00  16668.96
# 1 2005-03-10 08:01:01+00:00   3170.00
# 2 2005-03-10 08:01:01+00:00   5553.84
# 3 2005-03-10 08:01:01+00:00  25360.00
# 4 2005-03-10 08:01:15+00:00  25360.00

# %%
quotes.head()
# Out:
#    #RIC    Date[L] Quote Time  Bid Price  Bid Size  Ask Price  Ask Size  \
# 0  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 1  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 2  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 3  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
# 4  MSFT 2005-03-10    7:30:00       25.3         1      25.32         1
#
#   parse_time                 Timestamp  MidQuote  DepthOnTop  Spread  \
# 0   07:30:00 2005-03-10 07:30:00+00:00     25.31         1.0    0.02
# 1   07:30:00 2005-03-10 07:30:00+00:00     25.31         1.0    0.02
# 2   07:30:00 2005-03-10 07:30:00+00:00     25.31         1.0    0.02
# 3   07:30:00 2005-03-10 07:30:00+00:00     25.31         1.0    0.02
# 4   07:30:00 2005-03-10 07:30:00+00:00     25.31         1.0    0.02
#
#    RelSpread
# 0    0.00079
# 1    0.00079
# 2    0.00079
# 3    0.00079
# 4    0.00079

# %% [markdown]
# We want to focus on continuous trading.
#
# By 10:10 am, all stocks should be open, and they all stop at 4pm for an auction about 10 minutes later.

# %%
# We will focus on continuous trading. 
start_time = time(hour=10, minute=10)
end_time = time(hour=16, minute=0)

# %%
sel = ((trades.Timestamp.dt.time > start_time) &
       (trades.Timestamp.dt.time < end_time))

trades_open = trades[sel].copy()

# %%
sel = ((trades.Timestamp.dt.time > start_time) &
       (trades.Timestamp.dt.time < end_time))

trades_open = trades[sel].copy()

# %%
trades_open = trades_open.sort_values(['Timestamp', '#RIC'])
quotes = quotes.sort_values(['Timestamp', '#RIC'])

# %% [markdown]
# ## Spreads
#
# Two common measures for the cost of trading are the effective spread and the realized spread.
#
# The definition for each of them is the following:
#
# ### Effective spread
#
# Buy market order: $2\times (p_t - m_t)$
#
# Sell market order: $2\times (m_t - p_t)$
#
# where $p_t$ is the price for the transaction at time $t$, and $m_t$ is the mid quote at time $t-\varepsilon$ (just before the trade).
#
#
# ### Realized spread
#
# Buy market order: $2\times (p_t - m_{t+\Delta})$
#
# Sell market order: $2\times (m_{t+\Delta} - p_t)$
#
# where $p_t$ is the price for the transaction at time $t$, and $m_{t+\Delta}$ is the mid quote at time ${t+\Delta}$. A common value for $\Delta$ is 5 minutes, so we'll use that.

# %% [markdown]
# First, we need to merge trades and quotes at the right time.

# %%
trades_open['TS_5min'] = trades_open['Timestamp'] + timedelta(minutes=5)

# %%
taq_merged = pd.merge_asof(trades_open,
                           quotes[['#RIC', 'Timestamp', 'Bid Price', 'Ask Price', 'MidQuote']],
                           on='Timestamp', by='#RIC', allow_exact_matches=False)

taq_merged = pd.merge_asof(taq_merged,
                           quotes[['#RIC', 'Timestamp', 'Bid Price', 'Ask Price', 'MidQuote']],
                           left_on='TS_5min', right_on='Timestamp',
                           by='#RIC', suffixes=('', '_5min'),
                           allow_exact_matches=False)

# %%
taq_merged.head()
# Out:
#    #RIC    Date[L] Exch Time  Price  Volumn parse_time  \
# 0  MSFT 2005-03-10  10:10:01  25.35    1000   10:10:01
# 1  MSFT 2005-03-10  10:10:01  25.36     300   10:10:01
# 2  MSFT 2005-03-10  10:10:01  25.36     500   10:10:01
# 3  MSFT 2005-03-10  10:10:01  25.36     100   10:10:01
# 4  MSFT 2005-03-10  10:10:01  25.35     100   10:10:01
#
#                   Timestamp    Value                   TS_5min  Bid Price  \
# 0 2005-03-10 10:10:01+00:00  25350.0 2005-03-10 10:15:01+00:00      25.35
# 1 2005-03-10 10:10:01+00:00   7608.0 2005-03-10 10:15:01+00:00      25.35
# 2 2005-03-10 10:10:01+00:00  12680.0 2005-03-10 10:15:01+00:00      25.35
# 3 2005-03-10 10:10:01+00:00   2536.0 2005-03-10 10:15:01+00:00      25.35
# 4 2005-03-10 10:10:01+00:00   2535.0 2005-03-10 10:15:01+00:00      25.35
#
#    Ask Price  MidQuote            Timestamp_5min  Bid Price_5min  \
# 0      25.36    25.355 2005-03-10 10:15:00+00:00           25.35
# 1      25.36    25.355 2005-03-10 10:15:00+00:00           25.35
# 2      25.36    25.355 2005-03-10 10:15:00+00:00           25.35
# 3      25.36    25.355 2005-03-10 10:15:00+00:00           25.35
# 4      25.36    25.355 2005-03-10 10:15:00+00:00           25.35
#
#    Ask Price_5min  MidQuote_5min
# 0           25.36         25.355
# 1           25.36         25.355
# 2           25.36         25.355
# 3           25.36         25.355
# 4           25.36         25.355

# %% [markdown]
# We next need to "sign" the trades, figure out if it's a buy or a sell.

# %%
taq_merged['Sign'] = ''
taq_merged.loc[taq_merged.Price == taq_merged['Bid Price'], 'Sign'] = 'S'
taq_merged.loc[taq_merged.Price == taq_merged['Ask Price'], 'Sign'] = 'B'
taq_merged.loc[taq_merged.Price == taq_merged['MidQuote'], 'Sign'] = 'C' 
# Cross A cross trade is a practice where buy and sell orders for the same asset 
# are offset without recording the trade on the exchange. It is an activity that 
# is not permitted on most major exchanges.

# %%
taq_merged.head()
# Out:
#    #RIC    Date[L] Exch Time  Price  Volumn parse_time  \
# 0  MSFT 2005-03-10  10:10:01  25.35    1000   10:10:01
# 1  MSFT 2005-03-10  10:10:01  25.36     300   10:10:01
# 2  MSFT 2005-03-10  10:10:01  25.36     500   10:10:01
# 3  MSFT 2005-03-10  10:10:01  25.36     100   10:10:01
# 4  MSFT 2005-03-10  10:10:01  25.35     100   10:10:01
#
#                   Timestamp    Value                   TS_5min  Bid Price  \
# 0 2005-03-10 10:10:01+00:00  25350.0 2005-03-10 10:15:01+00:00      25.35
# 1 2005-03-10 10:10:01+00:00   7608.0 2005-03-10 10:15:01+00:00      25.35
# 2 2005-03-10 10:10:01+00:00  12680.0 2005-03-10 10:15:01+00:00      25.35
# 3 2005-03-10 10:10:01+00:00   2536.0 2005-03-10 10:15:01+00:00      25.35
# 4 2005-03-10 10:10:01+00:00   2535.0 2005-03-10 10:15:01+00:00      25.35
#
#    Ask Price  MidQuote            Timestamp_5min  Bid Price_5min  \
# 0      25.36    25.355 2005-03-10 10:15:00+00:00           25.35
# 1      25.36    25.355 2005-03-10 10:15:00+00:00           25.35
# 2      25.36    25.355 2005-03-10 10:15:00+00:00           25.35
# 3      25.36    25.355 2005-03-10 10:15:00+00:00           25.35
# 4      25.36    25.355 2005-03-10 10:15:00+00:00           25.35
#
#    Ask Price_5min  MidQuote_5min Sign
# 0           25.36         25.355    S
# 1           25.36         25.355    B
# 2           25.36         25.355    B
# 3           25.36         25.355    B
# 4           25.36         25.355    S

# %% [markdown]
# ### Effective Spread
#
# Buy market order: $2\times (p_t - m_t)$
#
# Sell market order: $2\times (m_t - p_t)$
#
# where $p_t$ is the price for the transaction at time $t$, and $m_t$ is the mid quote at time $t-\varepsilon$ (just before the trade).

# %%
# Create the variable for every obs
taq_merged['Effective Spread'] = np.nan
b_sel = taq_merged.Sign == 'B'
taq_merged.loc[b_sel, 'Effective Spread'] = 2*(taq_merged.loc[b_sel, 'Price'] -
                                               taq_merged.loc[b_sel, 'MidQuote'])
s_sel = taq_merged.Sign == 'S'
taq_merged.loc[s_sel, 'Effective Spread'] = 2*(taq_merged.loc[s_sel, 'MidQuote'] -
                                               taq_merged.loc[s_sel, 'Price'])

# %% [markdown]
# ### Realized spread
#
# Buy market order: $2\times (p_t - m_{t+\Delta})$
#
# Sell market order: $2\times (m_{t+\Delta} - p_t)$
#
# where $p_t$ is the price for the transaction at time $t$, and $m_{t+\Delta}$ is the mid quote at time ${t+\Delta}$. We use $\Delta=$5 minutes.

# %%
# Create the variable for every obs
taq_merged['Realized Spread'] = np.nan
b_sel = taq_merged.Sign == 'B'
taq_merged.loc[b_sel, 'Realized Spread'] = 2*(taq_merged.loc[b_sel, 'Price'] -
                                              taq_merged.loc[b_sel, 'MidQuote_5min'])
s_sel = taq_merged.Sign == 'S'
taq_merged.loc[s_sel, 'Realized Spread'] = 2*(taq_merged.loc[s_sel, 'MidQuote_5min'] -
                                              taq_merged.loc[s_sel, 'Price'])

# %% [markdown]
# **Note**: here we might choose to do something special for trades in the last 5 minutes, such as recomputing realized spread using the closing auction price instead of the midquote. We won't do it, meaning we're using the prevailing mid-quote at market close.

# %% [markdown]
# ### Price impact
#
# The realized spread is a measure of price impact, i.e., it measures how trades move prices. If prices move in the direction of the trade, realized spread becomes smaller and possibly negative. We might expect that price impact is related to trade size. To make everything comparable, we need to make the measures "relative" (i.e., in %) to something, either price or mid-quote. We use the prevailing mid-quote at trade time.

# %%
taq_merged['RelEffective Spread'] = taq_merged['Effective Spread'] / taq_merged['MidQuote']
taq_merged['RelRealized Spread'] = taq_merged['Realized Spread'] / taq_merged['MidQuote']

# %%
taq_merged.plot.scatter(x='Value', y='RelRealized Spread');
# Out:
# /Users/leah/anaconda3/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:420: FutureWarning: Converting timezone-aware DatetimeArray to timezone-naive ndarray with 'datetime64[ns]' dtype. In the future, this will return an ndarray with 'object' dtype where each element is a 'pandas.Timestamp' with the correct 'tz'.
# 	To accept the future behavior, pass 'dtype=object'.
# 	To keep the old behavior, pass 'dtype="datetime64[ns]"'.
#   numeric_data[col] = np.asarray(numeric_data[col])

# %% [markdown]
# Ok, so we have a few outliers, so it's hard to see what is going on. One way around this issue is to group trades in value deciles.

# %%
taq_merged['Value_q10'] = pd.qcut(taq_merged['Value'], q=10, labels=False)

# %%
taq_merged
# Out:
#        #RIC    Date[L] Exch Time  Price  Volumn parse_time  \
# 0      MSFT 2005-03-10  10:10:01  25.35    1000   10:10:01
# 1      MSFT 2005-03-10  10:10:01  25.36     300   10:10:01
# 2      MSFT 2005-03-10  10:10:01  25.36     500   10:10:01
# 3      MSFT 2005-03-10  10:10:01  25.36     100   10:10:01
# 4      MSFT 2005-03-10  10:10:01  25.35     100   10:10:01
# ...     ...        ...       ...    ...     ...        ...
# 72338  MSFT 2005-03-10  15:59:59  25.44     900   15:59:59
# 72339  MSFT 2005-03-10  15:59:59  25.44     300   15:59:59
# 72340  MSFT 2005-03-10  15:59:59  25.44    1700   15:59:59
# 72341  MSFT 2005-03-10  15:59:59  25.44     100   15:59:59
# 72342  MSFT 2005-03-10  15:59:59  25.44     500   15:59:59
#
#                       Timestamp    Value                   TS_5min  Bid Price  \
# 0     2005-03-10 10:10:01+00:00  25350.0 2005-03-10 10:15:01+00:00      25.35
# 1     2005-03-10 10:10:01+00:00   7608.0 2005-03-10 10:15:01+00:00      25.35
# 2     2005-03-10 10:10:01+00:00  12680.0 2005-03-10 10:15:01+00:00      25.35
# 3     2005-03-10 10:10:01+00:00   2536.0 2005-03-10 10:15:01+00:00      25.35
# 4     2005-03-10 10:10:01+00:00   2535.0 2005-03-10 10:15:01+00:00      25.35
# ...                         ...      ...                       ...        ...
# 72338 2005-03-10 15:59:59+00:00  22896.0 2005-03-10 16:04:59+00:00      25.42
# 72339 2005-03-10 15:59:59+00:00   7632.0 2005-03-10 16:04:59+00:00      25.42
# 72340 2005-03-10 15:59:59+00:00  43248.0 2005-03-10 16:04:59+00:00      25.42
# 72341 2005-03-10 15:59:59+00:00   2544.0 2005-03-10 16:04:59+00:00      25.42
# 72342 2005-03-10 15:59:59+00:00  12720.0 2005-03-10 16:04:59+00:00      25.42
#
#        ...            Timestamp_5min  Bid Price_5min Ask Price_5min  \
# 0      ... 2005-03-10 10:15:00+00:00           25.35          25.36
# 1      ... 2005-03-10 10:15:00+00:00           25.35          25.36
# 2      ... 2005-03-10 10:15:00+00:00           25.35          25.36
# 3      ... 2005-03-10 10:15:00+00:00           25.35          25.36
# 4      ... 2005-03-10 10:15:00+00:00           25.35          25.36
# ...    ...                       ...             ...            ...
# 72338  ... 2005-03-10 16:04:57+00:00           25.44          25.46
# 72339  ... 2005-03-10 16:04:57+00:00           25.44          25.46
# 72340  ... 2005-03-10 16:04:57+00:00           25.44          25.46
# 72341  ... 2005-03-10 16:04:57+00:00           25.44          25.46
# 72342  ... 2005-03-10 16:04:57+00:00           25.44          25.46
#
#        MidQuote_5min  Sign  Effective Spread Realized Spread  \
# 0             25.355     S              0.01            0.01
# 1             25.355     B              0.01            0.01
# 2             25.355     B              0.01            0.01
# 3             25.355     B              0.01            0.01
# 4             25.355     S              0.01            0.01
# ...              ...   ...               ...             ...
# 72338         25.450                     NaN             NaN
# 72339         25.450                     NaN             NaN
# 72340         25.450                     NaN             NaN
# 72341         25.450                     NaN             NaN
# 72342         25.450                     NaN             NaN
#
#        RelEffective Spread  RelRealized Spread  Value_q10
# 0                 0.000394            0.000394          9
# 1                 0.000394            0.000394          4
# 2                 0.000394            0.000394          6
# 3                 0.000394            0.000394          1
# 4                 0.000394            0.000394          1
# ...                    ...                 ...        ...
# 72338                  NaN                 NaN          8
# 72339                  NaN                 NaN          4
# 72340                  NaN                 NaN          9
# 72341                  NaN                 NaN          2
# 72342                  NaN                 NaN          7
#
# [72343 rows x 22 columns]

# %%
# ?pd.qcut

# %%
val_q10_mean = taq_merged.groupby('Value_q10')[['RelEffective Spread', 'RelRealized Spread', 
                                                'Effective Spread', 'Realized Spread']].mean().abs()

# %%
val_q10_mean[['RelEffective Spread', 'RelRealized Spread']].plot()

# %%
val_q10_mean[['Effective Spread', 'Realized Spread']].plot()

# %% [markdown]
# To get the average value for each stock/day, we can groupby.

# %%
spd_mean = taq_merged.groupby(['#RIC', 'Date[L]'])[['RelEffective Spread', 'RelRealized Spread', 
                               'Effective Spread', 'Realized Spread']].mean()
spd_mean
# Out:
#                  RelEffective Spread  RelRealized Spread  Effective Spread  \
# #RIC Date[L]
# MSFT 2005-03-10             -0.01007           -0.001766         -0.122407
#
#                  Realized Spread
# #RIC Date[L]
# MSFT 2005-03-10        -0.044912

# %%
# To get trade value-weighted average instead, it's not much harder.
cols = ['RelEffective Spread', 'RelRealized Spread',
        'Effective Spread', 'Realized Spread']
for c in cols:
    taq_merged[c + '_VW'] = taq_merged[c] * taq_merged['Value']

for c in cols:
    spd_mean[c + '_VW'] = (taq_merged.groupby(['#RIC', 'Date[L]'])[c + '_VW'].sum() /
                          taq_merged.groupby(['#RIC', 'Date[L]'])['Value'].sum())
spd_mean
# Out:
#                  RelEffective Spread  RelRealized Spread  Effective Spread  \
# #RIC Date[L]
# MSFT 2005-03-10             -0.01007           -0.001766         -0.122407
#
#                  Realized Spread  RelEffective Spread_VW  \
# #RIC Date[L]
# MSFT 2005-03-10        -0.044912               -0.011529
#
#                  RelRealized Spread_VW  Effective Spread_VW  \
# #RIC Date[L]
# MSFT 2005-03-10               0.000532             -0.14116
#
#                  Realized Spread_VW
# #RIC Date[L]
# MSFT 2005-03-10            0.013635

# %% [markdown]
# ## Time-weighted measures
#
# Another couple of interesting measures are the time-weighted spread and depth, which give an idea of the liquidity available. Since these are time-weighted, we take the average value, weighted by the duration of the spread or available depth.

# %%
# First, we need to compute the time interval. We cannot use diff() since we want the difference
# between the next timestamp (when a new quote/depth is set) and the current timestamp.

def parse_simple_time(t):
    # The data is up to the second precision.
    # print(t.split(":"))
    return timedelta(hours=int(t.split(":")[0]), minutes=int(t.split(":")[1]),
                     seconds=int(t.split(":")[2]))

quotes["parse_time"] = quotes["Quote Time"].apply(parse_simple_time)
# q1 = quotes.groupby('#RIC')['Quote Time'].shift(-1)

quotes['time_d'] = (quotes.groupby('#RIC')['parse_time'].shift(-1) - quotes['parse_time']).dt.total_seconds()

# %%
quotes
# Out:
#         #RIC    Date[L] Quote Time  Bid Price  Bid Size  Ask Price  Ask Size  \
# 0       MSFT 2005-03-10    7:30:00      25.30         1      25.32         1
# 1       MSFT 2005-03-10    7:30:00      25.30         1      25.32         1
# 2       MSFT 2005-03-10    7:30:00      25.30         1      25.32         1
# 3       MSFT 2005-03-10    7:30:00      25.30         1      25.32         1
# 4       MSFT 2005-03-10    7:30:00      25.30         1      25.32         1
# ...      ...        ...        ...        ...       ...        ...       ...
# 265039  MSFT 2005-03-10   18:27:52      25.44         4      25.53        88
# 265040  MSFT 2005-03-10   18:30:00      25.24        15      25.65        15
# 265041  MSFT 2005-03-10   18:30:00      25.24        15      25.65        15
# 265042  MSFT 2005-03-10   18:30:02       0.00         0       0.00         0
# 265043  MSFT 2005-03-10   18:32:03       0.00         0       0.00         0
#
#        parse_time                 Timestamp  MidQuote  DepthOnTop  Spread  \
# 0        07:30:00 2005-03-10 07:30:00+00:00    25.310         1.0    0.02
# 1        07:30:00 2005-03-10 07:30:00+00:00    25.310         1.0    0.02
# 2        07:30:00 2005-03-10 07:30:00+00:00    25.310         1.0    0.02
# 3        07:30:00 2005-03-10 07:30:00+00:00    25.310         1.0    0.02
# 4        07:30:00 2005-03-10 07:30:00+00:00    25.310         1.0    0.02
# ...           ...                       ...       ...         ...     ...
# 265039   18:27:52 2005-03-10 18:27:52+00:00    25.485        46.0    0.09
# 265040   18:30:00 2005-03-10 18:30:00+00:00    25.445        15.0    0.41
# 265041   18:30:00 2005-03-10 18:30:00+00:00    25.445        15.0    0.41
# 265042   18:30:02 2005-03-10 18:30:02+00:00     0.000         0.0    0.00
# 265043   18:32:03 2005-03-10 18:32:03+00:00     0.000         0.0    0.00
#
#         RelSpread  time_d
# 0        0.000790     0.0
# 1        0.000790     0.0
# 2        0.000790     0.0
# 3        0.000790     0.0
# 4        0.000790  1630.0
# ...           ...     ...
# 265039   0.003531   128.0
# 265040   0.016113     0.0
# 265041   0.016113     2.0
# 265042        NaN   121.0
# 265043        NaN     NaN
#
# [265044 rows x 14 columns]

# %%
# Next, we do as before, using 'time_d' instead of Value for our weights.
cols = ['Spread', 'RelSpread', 'DepthOnTop']
for c in cols:
    quotes[c + '_TW'] = quotes[c] * quotes['time_d']

tw_mean = quotes.groupby(['#RIC', 'Date[L]'])[[c + '_TW' for c in cols]].sum()
    
for c in cols:
    tw_mean[c + '_TW'] = (tw_mean[c + '_TW'] /
                          quotes.groupby(['#RIC', 'Date[L]'])['time_d'].sum())
tw_mean
# Out:
#                  Spread_TW  RelSpread_TW  DepthOnTop_TW
# #RIC Date[L]
# MSFT 2005-03-10  14.846043      0.036838     243.707701

# %%
# Now we can merge our two datasets

merged = pd.merge(spd_mean, tw_mean, left_index=True, right_index=True)
merged
# Out:
#                  RelEffective Spread  RelRealized Spread  Effective Spread  \
# #RIC Date[L]
# MSFT 2005-03-10             -0.01007           -0.001766         -0.122407
#
#                  Realized Spread  RelEffective Spread_VW  \
# #RIC Date[L]
# MSFT 2005-03-10        -0.044912               -0.011529
#
#                  RelRealized Spread_VW  Effective Spread_VW  \
# #RIC Date[L]
# MSFT 2005-03-10               0.000532             -0.14116
#
#                  Realized Spread_VW  Spread_TW  RelSpread_TW  DepthOnTop_TW
# #RIC Date[L]
# MSFT 2005-03-10            0.013635  14.846043      0.036838     243.707701
